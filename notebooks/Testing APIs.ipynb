# %% [markdown]
# # Testing APIs

# %%
import re
import requests
import pandas as pd
import json

# %%
#Trip Advisor

# %%
url = "https://tripadvisor16.p.rapidapi.com/api/v1/restaurant/searchRestaurants"

querystring = {"locationId":"187514","page":"100"}

headers = {
    "X-RapidAPI-Key": "ce9be7a049mshef2a2232297f2a4p1474fajsnab7073b68af0",
    "X-RapidAPI-Host": "tripadvisor16.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

trip_rest = response.json()

# %%
rest1 = pd.json_normalize(trip_rest)

# %%
rest2 = rest1.explode('data.data')

# %%
pd.set_option('display.max_columns', 500)
rest3 = pd.json_normalize(rest2['data.data'])
rest3.head()
# Out:
#                                        restaurantsId  \
# 0  Restaurant_Review-g187514-d24902091-Reviews-Os...
# 1  Restaurant_Review-g187514-d4296306-Reviews-Don...
# 2  Restaurant_Review-g187514-d13576981-Reviews-Bo...
# 3  Restaurant_Review-g187514-d9807742-Reviews-La_...
# 4  Restaurant_Review-g187514-d8374900-Reviews-Bar...
#
#                                           heroImgUrl  heroImgRawHeight  \
# 0  https://media-cdn.tripadvisor.com/media/photo-...               450
# 1  https://media-cdn.tripadvisor.com/media/photo-...               450
# 2  https://media-cdn.tripadvisor.com/media/photo-...               291
# 3  https://media-cdn.tripadvisor.com/media/photo-...               309
# 4  https://media-cdn.tripadvisor.com/media/photo-...               413
#
#    heroImgRawWidth squareImgUrl  squareImgRawLength  locationId  \
# 0              450                                0    24902091
# 1              450                                0     4296306
# ...

# %%
rest2
# Out:
#    status  message      timestamp data.totalRecords  data.totalPages  \
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# 0    True  Success  1675520191641             10479              350
# ...

# %%
madrid = pd.read_csv('actividadeconomica202301.csv',sep=';')
madrid.head()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9416\4205195400.py:1: DtypeWarning: Columns (42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   madrid = pd.read_csv('actividadeconomica202301.csv',sep=';')
#     id_local  id_distrito_local   desc_distrito_local  id_barrio_local  \
# 0  285003375                  1  CENTRO                            105
# 1  285003387                  1  CENTRO                            105
# 2  285003390                  1  CENTRO                            105
# 3  285003397                  1  CENTRO                            105
# 4  285003400                  1  CENTRO                            105
#
#       desc_barrio_local  cod_barrio_local  id_seccion_censal_local  \
# 0  UNIVERSIDAD                          5                     1097
# 1  UNIVERSIDAD                          5                     1097
# 2  UNIVERSIDAD                          5                     1097
# ...

# %%
madrid.shape
# Out:
# (168547, 49)

# %%
restaurantes = madrid[madrid['desc_seccion']=="HOSTELERÍA"]

# %%
restaurantes['desc_epigrafe'].value_counts()
# Out:
# BAR CON COCINA                                                                            4544
# BAR RESTAURANTE                                                                           4532
# CAFETERIA                                                                                 3342
# RESTAURANTE                                                                               2826
# BAR SIN COCINA                                                                            1758
# SERVICIOS DE COMEDOR EN CENTROS EDUCATIVOS Y CENTROS DE CUIDADO INFANTIL                  1431
# BAR ESPECIAL SIN ACTUACIONES                                                               910
# RESTAURANTES DE COMIDA RAPIDA                                                              611
# SERVICIOS DE COMEDOR EN CENTROS PARA MAYORES                                               355
# HOTELES Y MOTELES CON RESTAURANTE                                                          333
# ...

# %%
poblacion = pd.read_csv('poblacion_1_enero.csv',sep=';')
poblacion.head()
# Out:
#                 fecha  cod_municipio municipio cod_distrito     distrito  \
# 0  1 de enero de 2021          28079    Madrid           01       Centro
# 1  1 de enero de 2021          28079    Madrid           02   Arganzuela
# 2  1 de enero de 2021          28079    Madrid           03       Retiro
# 3  1 de enero de 2021          28079    Madrid           04    Salamanca
# 4  1 de enero de 2021          28079    Madrid           05    Chamartín
#
#   cod_barrio      barrio num_personas num_personas_hombres  \
# 0         01      Centro      141.236               71.881
# 1         02  Arganzuela      154.243               72.000
# 2         03      Retiro      118.557               53.800
# 3         04   Salamanca      146.016               64.540
# 4         05   Chamartín      145.700               65.599
#
#   num_personas_mujeres
# 0               69.355
# 1               82.243
# 2               64.757
# 3               81.476
# 4               80.101

# %%
poblacion.shape
# Out:
# (612, 10)

# %%
recent = poblacion[poblacion['fecha']=='1 de enero de 2021']
recent.tail()
# Out:
#                   fecha  cod_municipio municipio cod_distrito  distrito  \
# 148  1 de enero de 2021          28079    Madrid           21   Barajas
# 149  1 de enero de 2021          28079    Madrid           21   Barajas
# 150  1 de enero de 2021          28079    Madrid           21   Barajas
# 151  1 de enero de 2021          28079    Madrid           21   Barajas
# 152  1 de enero de 2021          28079    Madrid        Todos     Todos
#
#     cod_barrio                   barrio num_personas num_personas_hombres  \
# 148        212               Aeropuerto        1.918                  988
# 149        213  CascoHistóricodeBarajas        7.504                3.593
# 150        214                    Timón       13.334                6.379
# 151        215               Corralejos        7.664                3.781
# 152      Todos                    Todos    3.312.310            1.545.157
#
#     num_personas_mujeres
# 148                  930
# 149                3.911
# ...

# %%
import lxml

# %%
tourist_rest = pd.read_xml('restaurantes_turisticos.xml',xpath='//serviceList/service/basicData')
                           
tourist_rest
# Out:
#     language           name                            email  \
# 0         en        Omeraki      Info@omerakirestaurante.com
# 1         en           Abya                 reservas@abya.es
# 2         en    Zuara Sushi              info@zuarasushi.com
# 3         en       Ugo Chan             reservas@ugochan.com
# 4         en        Azumbre              reservas@azumbre.es
# ..       ...            ...                              ...
# 957       en  Allard Madrid         reservas@allardmadrid.es
# 958       en    La Trainera              resta@latrainera.es
# 959       en         Laredo         laredo@tabernalaredo.com
# 960       en       Dantxari         restaurante@dantxari.com
# 961       en    El Paraguas  restauranteelparaguas@gmail.com
#
#                   phone  fax          title  \
# 0     (+34) 910 880 327  NaN        Omeraki
# 1                  None  NaN           Abya
# 2     (+34) 633 467 780  NaN    Zuara Sushi
# 3     (+34) 913 506 578  NaN       Ugo Chan
# ...

# %%
geo_tourist_rest = pd.read_xml('restaurantes_turisticos.xml',xpath='//serviceList/service/geoData')
                           
geo_tourist_rest
# Out:
#                          address  zipcode locality country   latitude  \
# 0         del Duque de Sesto, 27  28009.0     None   Spain  40.422605
# 1    de José Ortega y Gasset, 32  28006.0     None   Spain  40.430014
# 2            del Pensamiento, 28  28020.0     None   Spain  40.458734
# 3                  Félix Boix, 6  28036.0     None   Spain  40.463226
# 4              Eduardo Dato Nº13  28010.0   Madrid   Spain  40.433177
# ..                           ...      ...      ...     ...        ...
# 957                 de Ferraz, 2  28008.0     None   Spain  40.423171
# 958                  Lagasca, 60  28001.0     None   Spain  40.427183
# 959       del Doctor Castelo, 30  28009.0     None   Spain  40.420211
# 960         Ventura Rodríguez, 8  28008.0     None   Spain  40.425551
# 961               Jorge Juan, 16  28001.0     None   Spain  40.423076
#
#      longitude subAdministrativeArea
# 0    -3.675309                Madrid
# 1    -3.681281                Madrid
# ...

# %%
restaurantes_turisticos = pd.concat([tourist_rest,geo_tourist_rest],axis=1)

# %%
restaurantes_turisticos.to_csv('restaurantes_turisticos.csv')

# %% [markdown]
# # Google API

# %%
import getpass

# %%
my_api = getpass.getpass()
# Out:
# ········

# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants%20in%20Madrid&key=AIzaSyAr9jbSFYgP1fHjPRCWQEMLPufszolOeZA"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

first_page = response.json()

# %% [markdown]
# # First set of requests

# %%
first_page
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AfLeUgPse8e7pqWuqk0D9ZdCAlqLc9Dy2xE2CYkjyOms-NR8gr4Rlq34xrMlz2DdSPUrwpzXUpyx3TWRZJUEdxWgHjoFoeU7pWOUb22zbTqjXw7XK5EbDuUHhajgpWvwgd6iYHjl6eSBL5rF7HVKCFmIjRcS4FYJG6zgybzEErtIC43DjMxJU2nCpTqi_pgrWAFMPCmV1Q_js-uD0B0fizZj_2L8QraBO38GqXIZOvsmjFn3FthLuxiGup2VdKQ090PYHmZrnEylONPs6gMhAy8rMFLIRZiCwd0-3K60gBUWbtK15mJjLynGXky4c1cuduMTUj07RkAlcPfqw5HIIR5zGfzX4V163JirMh646F1RS1ae026HUvuQFvPa5-kF-ezCMqM1UmB1nCwVVtZtWzwE5SctMg',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'C. de las Huertas, 24, 28014 Madrid, Spain',
#    'geometry': {'location': {'lat': 40.41364850000001, 'lng': -3.6994512},
#     'viewport': {'northeast': {'lat': 40.41505077989272,
#       'lng': -3.698114720107278},
#      'southwest': {'lat': 40.41235112010728, 'lng': -3.700814379892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
# ...

# %%
first_page = pd.json_normalize(first_page['results'])

# %%
first_page
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL         C. de las Huertas, 24, 28014 Madrid, Spain
# 1      OPERATIONAL  C. de la Torrecilla del Leal, 12, 28012 Madrid...
# 2      OPERATIONAL               C/ Gran Vía, 16, 28013 Madrid, Spain
# 3      OPERATIONAL                C/ Gran Vía, 4, 28013 Madrid, Spain
# 4      OPERATIONAL         C. de Sta. Isabel, 35, 28012 Madrid, Spain
# 5      OPERATIONAL                 Pl. Mayor, 30, 28012 Madrid, Spain
# 6      OPERATIONAL        Calle de Chinchilla, 3, 28013 Madrid, Spain
# 7      OPERATIONAL               C/ Gran Vía, 55, 28013 Madrid, Spain
# 8      OPERATIONAL             C. del Arenal, 26, 28013 Madrid, Spain
# 9      OPERATIONAL              C. de Atocha, 57, 28012 Madrid, Spain
# 10     OPERATIONAL        Cra de S. Jerónimo, 16, 28014 Madrid, Spain
# 11     OPERATIONAL           C. de Preciados, 32, 28013 Madrid, Spain
# ...

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants%20in%20Madrid&key=AIzaSyAr9jbSFYgP1fHjPRCWQEMLPufszolOeZA&pagetoken=AfLeUgPse8e7pqWuqk0D9ZdCAlqLc9Dy2xE2CYkjyOms-NR8gr4Rlq34xrMlz2DdSPUrwpzXUpyx3TWRZJUEdxWgHjoFoeU7pWOUb22zbTqjXw7XK5EbDuUHhajgpWvwgd6iYHjl6eSBL5rF7HVKCFmIjRcS4FYJG6zgybzEErtIC43DjMxJU2nCpTqi_pgrWAFMPCmV1Q_js-uD0B0fizZj_2L8QraBO38GqXIZOvsmjFn3FthLuxiGup2VdKQ090PYHmZrnEylONPs6gMhAy8rMFLIRZiCwd0-3K60gBUWbtK15mJjLynGXky4c1cuduMTUj07RkAlcPfqw5HIIR5zGfzX4V163JirMh646F1RS1ae026HUvuQFvPa5-kF-ezCMqM1UmB1nCwVVtZtWzwE5SctMg"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

second_page = response.json()

# %%
second_page
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AfLeUgPdF83ZTLVivSduzScmW9PguwIj_XdGQ57fOo_8f1a_q4ZfgCoOYvnhLIEmW2ysNm3qicGnYTY8B6asH_JAotSERgLy7T0_9TmVDTb-8Wdo9NrGtwcL8EnhZQR1n-hAApBRcopzVuM22LTwGfA8-JHp0CesCOX8cQpl4nyMaQsFVd2yL-O27Ybp4j_LGZqF4vpVG-UX-YzTAdLin3IOJ7faMyOJuOELDFENYOl_yk64vM25dwnpckYce1SWPL1duPwDlkO0SPcxbrUM5hJi1stbCf38zpJLhMZZf7StBEyGTjg4-M7HLT0Is83-9A-d1Foum7qVcYX20kt_O6VlJ2C4RsQUyn6vH-ASKyqJKQ8o4ROwpp80l7beB2HtP8GK1krJ5uRKcCTmnB-oU9IujtsY0Z6IhGIvtSL_T5HPTfzePHgGIqvdBccp3f_qgJmW37tm1JgPpbrSc78_LtUKkTD3oAxy5nxdfIwQs6AymN0_RtqopRCctvbntXea4YhTAGih8HgeHd1wD6qktO-nSQ0vXHhWF2e7D7i1Xp1mDKslpIIB5JJqg-CIzOalYIC5rApU_NDlFXIMqUUNNXXtsuuwA7FdwSUKV4-yVwgYL7-v0X4',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Pl. de la Marina Española, 7, 28013 Madrid, Spain',
#    'geometry': {'location': {'lat': 40.4203963, 'lng': -3.7125287},
#     'viewport': {'northeast': {'lat': 40.42179672989272,
#       'lng': -3.711230570107278},
# ...

# %%
second_page_df = pd.json_normalize(second_page['results'])

# %%
second_page_df
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL  Pl. de la Marina Española, 7, 28013 Madrid, Spain
# 1      OPERATIONAL     Cuesta de Sto. Domingo, 5, 28013 Madrid, Spain
# 2      OPERATIONAL       C. de Hernán Cortés, 19, 28004 Madrid, Spain
# 3      OPERATIONAL  Hotel Mayorazgo, C. de la Flor Baja, 3, 28013 ...
# 4      OPERATIONAL             C. de Regueros, 7, 28004 Madrid, Spain
# 5      OPERATIONAL          C. de las Huertas, 1, 28012 Madrid, Spain
# 6      OPERATIONAL            C. del Almendro, 9, 28005 Madrid, Spain
# 7      OPERATIONAL                C. de Cádiz, 4, 28012 Madrid, Spain
# 8      OPERATIONAL   Calle de Claudio Coello, 24, 28001 Madrid, Spain
# 9      OPERATIONAL         C. de Cuchilleros, 17, 28005 Madrid, Spain
# 10     OPERATIONAL             C. de Ponzano, 11, 28010 Madrid, Spain
# 11     OPERATIONAL     Calle de Sta. Catalina, 3, 28014 Madrid, Spain
# ...

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants%20in%20Madrid&key=AIzaSyAr9jbSFYgP1fHjPRCWQEMLPufszolOeZA&pagetoken=AfLeUgPdF83ZTLVivSduzScmW9PguwIj_XdGQ57fOo_8f1a_q4ZfgCoOYvnhLIEmW2ysNm3qicGnYTY8B6asH_JAotSERgLy7T0_9TmVDTb-8Wdo9NrGtwcL8EnhZQR1n-hAApBRcopzVuM22LTwGfA8-JHp0CesCOX8cQpl4nyMaQsFVd2yL-O27Ybp4j_LGZqF4vpVG-UX-YzTAdLin3IOJ7faMyOJuOELDFENYOl_yk64vM25dwnpckYce1SWPL1duPwDlkO0SPcxbrUM5hJi1stbCf38zpJLhMZZf7StBEyGTjg4-M7HLT0Is83-9A-d1Foum7qVcYX20kt_O6VlJ2C4RsQUyn6vH-ASKyqJKQ8o4ROwpp80l7beB2HtP8GK1krJ5uRKcCTmnB-oU9IujtsY0Z6IhGIvtSL_T5HPTfzePHgGIqvdBccp3f_qgJmW37tm1JgPpbrSc78_LtUKkTD3oAxy5nxdfIwQs6AymN0_RtqopRCctvbntXea4YhTAGih8HgeHd1wD6qktO-nSQ0vXHhWF2e7D7i1Xp1mDKslpIIB5JJqg-CIzOalYIC5rApU_NDlFXIMqUUNNXXtsuuwA7FdwSUKV4-yVwgYL7-v0X4"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

third_response = response.json()

# %%
third_response
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Pl. de Cascorro, 2, 28005 Madrid, Spain',
#    'geometry': {'location': {'lat': 40.4111579, 'lng': -3.7071081},
#     'viewport': {'northeast': {'lat': 40.41250332989273,
#       'lng': -3.705807220107278},
#      'southwest': {'lat': 40.40980367010728, 'lng': -3.708506879892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Sahuaro Madrid',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1200,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118392376041669428761">William Calderón</a>'],
# ...

# %%
third_page = pd.json_normalize(third_response['results'])

# %%
one_and_two = pd.concat([first_page,second_page_df],axis=0).reset_index()

# %%
firstsixty = pd.concat([one_and_two,third_page],axis=0).reset_index()

# %%
firstsixty.drop(columns=['level_0','index'],inplace=True)

# %%
firstsixty.to_csv('firstsixtygoogle.csv')

# %%
import pandas as pd
data = pd.read_csv('firstsixtygoogle.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'business_status', 'formatted_address', 'icon',
#        'icon_background_color', 'icon_mask_base_uri', 'name', 'photos',
#        'place_id', 'price_level', 'rating', 'reference', 'types',
#        'user_ratings_total', 'geometry.location.lat', 'geometry.location.lng',
#        'geometry.viewport.northeast.lat', 'geometry.viewport.northeast.lng',
#        'geometry.viewport.southwest.lat', 'geometry.viewport.southwest.lng',
#        'opening_hours.open_now', 'plus_code.compound_code',
#        'plus_code.global_code'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',100)

# %%
data.head()
# Out:
#    Unnamed: 0 business_status  \
# 0           0     OPERATIONAL
# 1           1     OPERATIONAL
# 2           2     OPERATIONAL
# 3           3     OPERATIONAL
# 4           4     OPERATIONAL
#
#                                    formatted_address  \
# 0         C. de las Huertas, 24, 28014 Madrid, Spain
# 1  C. de la Torrecilla del Leal, 12, 28012 Madrid...
# 2               C/ Gran Vía, 16, 28013 Madrid, Spain
# 3                C/ Gran Vía, 4, 28013 Madrid, Spain
# 4         C. de Sta. Isabel, 35, 28012 Madrid, Spain
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
# ...

# %%
data['price_level'].value_counts()
# Out:
# 2.0    33
# 1.0    12
# 3.0     7
# 4.0     1
# Name: price_level, dtype: int64

# %% [markdown]
# # Second set of requests

# %%
import re
import requests
import pandas as pd
import json

# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants&location=40.494742647684795,-3.6939811706542973&radius=50000&region=es&type=restaurant&key=AIzaSyCTikq4DDzQxEd2UfsgSr-S3ImmOfAvbt8"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

first_page = response.json()

# %%
first_page
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AfLeU

#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Carr. de El Pardo a Fuencarral, Km. 1.9, 28049 Madrid',
#    'geometry': {'location': {'lat': 40.5047538, 'lng': -3.7167438},
# ...

# %%
second_df = pd.json_normalize(first_page['results'])

# %%
import requests

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants&location=40.494742647684795,-3.6939811706542973&radius=50000&region=es&type=restaurant&key=AIzaSyCTikq4DDzQxEd2UfsgSr-S3ImmOfAvbt8&pagetoken=AfLeUgPNQTQ5BpefVRKcRZO496sfW0b8F0vswOEKL-ve_2JOb222x8p_I5we3wfPYld8WOot8blzn-r8lD9n-iYb3Rln8theyEugwPWDJbJzexP6fRbigD8I9et_FIfy9XvESbNQ_gMUNE2bml2wK0BITsMC7lLkEhN07LW3s0eeI469ddeyNF3eHdao1sMmm6NvLlt32_sVhYZjOoOxe4FgCdX21l6Wpn9fGtWM-0yAaTCnEq9DOunkUU-KGXZnpg7uVMtYy8_qZKE75Km_a6I1S7B0B1xyU_y8AlWUwGQ5E_1SgVeC96KiEZBuNT00PtQ1E7h1dzmTdWyYg9UVVyH8v5wxCl4qgZzBLC5pFjPy8ylzgSEAeaduObnh9SAwRoW1ePgtDWJDttLHyR6Wb3ARu0_uIpn5dHk5K9-JRyFa-zXIz263OqpREyjtgmWHdj1PCBAO9BwMKNJmkR1Tc9AbSUUnrvAbgS3Pgqokwk300x1nw0c_j8fD-JfKch25demWzKgUe9ShpA3qn0zGCIMZTwGWKzo5o24myhQsRtJp7rojfv3pwGhTDe3l8ZuTOZpjHmhzktEIPSH830AZZz1RgtAuCF9seYlc7ns6SQmYsioVPUNWIPRPTo_99Rszl4t86oKodqLYKiOn68SrHBtOtwbRMTen370Nih1MZTgKIWl21Qx2"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

third_page = response.json()

# %%
third_df = pd.json_normalize(third_page['results'])

# %%
one_and_two = pd.concat([first_df,second_df],axis=0).reset_index()

# %%
secondsixty = pd.concat([one_and_two,third_df],axis=0).reset_index()

# %%
secondsixty.to_csv('secondsixtygoogle.csv')

# %% [markdown]
# # Third set of requests

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants&location=40.50505471769747,-3.6651420593261723&radius=5000&region=es&type=restaurant&key=AIzaSyCTikq4DDzQxEd2UfsgSr-S3ImmOfAvbt8"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

f_page = response.json()

# %%
f_page
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AfLeUgOMpmuJvdFBFOYVXQhQECzmrHsPWwMdcSl5w6TeXhLUw6GPQ7WIeO4FK9YZnFoIFrCjJFH-1mKcmj5X_ZSPXj5ZZxPqXHnAQ6aU0FfeCg3NECl_zdEVSkcR_zYU4XCMbPibjo7whZdtjjdFLsp4xqzdu_yow5S6fXYzS1BzxX9Tr_aWwFvf9wbBPsVih5ZecKwl3pFXgDDES5qKAVPdxbNIUomKutj4RPHQ4sjbCm3jD9YYJhqB8BlyMq67dDTAh2TzoyOx5DHrkdCpa9XfSrMX3e6-gXYRYZmep2CujULs_F6Twt8aNs6yUdVoOkx9mg9rzrfZniErBEGYLIWjDgW2cUpzcJXKpJcyQvk_eSwCyqffYtH6s36Vgeo3lcyGuVPUKmryp9Qfbk7ugzpt580cb2qex7ZbLanMIPbaU3olM0a-DpyFq1ueV5BudSwBR5JGDib9_FYaBfDFjf3IGC9brno',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'C. de Antonio López Aguado, 12, 28029 Madrid',
#    'geometry': {'location': {'lat': 40.4822858, 'lng': -3.7015321},
#     'viewport': {'northeast': {'lat': 40.48359222989272,
#       'lng': -3.700142570107278},
#      'southwest': {'lat': 40.48089257010728, 'lng': -3.702842229892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
La6TBuOpadzlGg6EQ70z0O5bbm593TEbWOtJvpk7_teo3x3DA_x3fGMEfO4rCnwz9v9mcE9HjmO4C0cuS31QLbCMemW7HxaI5Fq_xxJz7A5AdXus0A3Iok5Ve4RpkQUKZpNHW-JILEROhwBfdpPgH9GmdbXH5GZ1rdNtoN4EvYCs0yYZkxfksOapu1eDWzrZ-xkS5hKssykUUqzoOS3qezA2VyMQ-zDtXQZsxni17QMygKHqrtAhJckh5admWxXoATB5I2yd_dcb4U0KihdQOm4L02R0T_X61COd2YmLsezdlFNogrfK4YdKGeQ48vzbnkfX3nxvc5JwMwrf_Aq0r5_PgHehtDLhTNpOv1XTL-ljVyJym-7Rho_rAPbe3muYN4EGbdBoAfnGKvtd57BX7yh9RNg4"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

t_page = response.json()

# %%
t_page
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'C. del Padre Damián, 44, 28036 Madrid',
#    'geometry': {'location': {'lat': 40.4596161, 'lng': -3.6851637},
#     'viewport': {'northeast': {'lat': 40.46097227989272,
#       'lng': -3.683963320107277},
#      'southwest': {'lat': 40.45827262010728, 'lng': -3.686662979892721}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'El Telégrafo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2395,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113940093985814064013">NovaQuality NQ</a>'],
# ...

# %%
t_df=pd.json_normalize(t_page['results'])

# %%
oneandtwo = pd.concat([f_df,s_df],axis=0).reset_index()

# %%
thirdsixty = pd.concat([oneandtwo, t_df],axis=0).reset_index()

# %%
thirdsixty.to_csv('thirdsixtygoogle.csv')

# %% [markdown]
# # Fourth set of requests

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants&location=40.489324912563376,-3.656301498413086&radius=5000&region=es&type=restaurant&key=AIzaSyCTikq4DDzQxEd2UfsgSr-S3ImmOfAvbt8"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

f_page = response.json()

# %%
f_page
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AfLeUgNMqDIRRLOpDErF1WdHfoM9pvmzCU7Z8mxfTBIeerDVnRQxKchgwMuAfuXUBahRO4HT8RA1SjyN9I05oKz-0y4MU5OUfMBPyf-H__s51-3SGhphB4-kEFdgWgIC6_cQPcsjNsp-zSYJ-dVQGTRDjGRBYeGfXYtNFWc5mYmWdAGYPhQnRhO_-NdI1yYqcGdczTjB56hAkqBDKkxTTPMf4mSxHpOo0mgwT5OC1QG64nXScr8SRE6P1LEW8SfjJEQQLrOOrN1L3_6McItbPM5cht1H6s4GPsefAepxM5KL3WPGk8vda7bekWH-Esh8ZF8DSrd4VacjLuda3iZHt0dS4gqc8roRKr0p_diB3SdSNzzoziUtBw1ZKHQcdedF8HiqAWqUAa2O3qFMF4e0ky6VA64qEOMHhjIsStTo7gUhnrLWS2uD9nNZMOzv0uxtJocp0YlDHkk8Bi0pLjQbwwBKplQSIx8',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'C. del Príncipe de Vergara, 210, 28002 Madrid',
#    'geometry': {'location': {'lat': 40.4512277, 'lng': -3.6772258},
#     'viewport': {'northeast': {'lat': 40.45279207989272,
#       'lng': -3.675835470107279},
#      'southwest': {'lat': 40.45009242010727, 'lng': -3.678535129892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
# ...

# %%
pd.json_normalize(f_page['results'])
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONA

#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'C. del Pensamiento, 4, 28020 Madrid',
#    'geometry': {'location': {'lat': 40.459552, 'lng': -3.698684999999999},
#     'viewport': {'northeast': {'lat': 40.46091827989272,
# ...

# %%
pd.json_normalize(s_page['results'])
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL                C. del Pensamiento, 4, 28020 Madrid
# 1      OPERATIONAL                     C. de Orense, 34, 28020 Madrid
# 2      OPERATIONAL        Av. de Alberto de Alcocer, 26, 28036 Madrid
# 3      OPERATIONAL           C. de Arturo Baldasano, 22, 28043 Madrid
# 4      OPERATIONAL             C. de Bravo Murillo, 298, 28020 Madrid
# 5      OPERATIONAL  C.C Arturo Soria Plaza, C. de Arturo Soria, 12...
# 6      OPERATIONAL      C. de la Condesa de Venadito, 1, 28027 Madrid
# 7      OPERATIONAL        C. de la Infanta Mercedes, 79, 28020 Madrid
# 8      OPERATIONAL                    C. de Silvano, 92, 28043 Madrid
# 9      OPERATIONAL       C. del Poeta Joan Maragall, 19, 28020 Madrid
# 10     OPERATIONAL        Calle de Modesto Lafuente, 76, 28003 Madrid
# 11     OPERATIONAL  Calle Alustante, 11, C. de Clara del Rey, 33, ...
# ...

# %%
df_2=pd.json_normalize(s_page['results'])

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants&location=40.489324912563376,-3.656301498413086&radius=5000&region=es&type=restaurant&key=AIzaSyCTikq4DDzQxEd2UfsgSr-S3ImmOfAvbt8&pagetoken=AfLeUgNMIF2sk8AtSZrc08nW5w0V5W4Lywq-KKGSAXcmWfHAe78hKH3cIn2Woqxo4feiDxtuH35UaXC5itXDxsuvBUO2QKERU4yqolDUiHamZpCqEnd8nUdOMj5qgK5HoOg8a-oAt3DbrUANr777nPhhiPCm14uvplldwycnmrXBlAIlCkxrBdVw9ON76O-nlOe298lLBycmMohSxMXDIo5E64vuIPwMn5r7Y3zZXHEl15xO-vat1jg66QA3ENj9AFynI7S7dzKAmWlp8PMXZmRZ55gSmKJ8XSzdK34ipmop64I5S3lWM6T78PARS61jbPEBpTFz8EoulOPkDFCHyhZAnms5JFGqP6F4RGP7_Q5D0Fmx_atqhBoPqInmu9vmaI_i-aIyQOekfxZBJ5LQgFuHSkWkugnBD9oVDM03zoS0sRMFtu4rG4RN-dEMIEyaR9c3vKg24hhGbq7yW-vR3cmFJBuKDRh9nUDDVbtj_0V60ZZUZEvegK_eLTvx7e3PmUGiE1RM80YvwvWnzXmy_UtKDQ8GlAdmhwER7FpS0wf24ekPESlqPAITJdbGRJHyOFu1kj98EjqxiFsvPnTNwCPBBLGlb8AHWJNmTXbTwNW6filEl_clyzeuoHWu4JztE85yQNIkpRlNvdBdBTCJdv9-7oH73bkNRwo7rBaUsjmxft0F_dg9"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

t_page = response.json()

# %%
t_page
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'C. de San Modesto, 44, 28034 Madrid',
#    'geometry': {'location': {'lat': 40.4858632, 'lng': -3.6926373},
#     'viewport': {'northeast': {'lat': 40.48713637989272,
#       'lng': -3.691364420107278},
#      'southwest': {'lat': 40.48443672010728, 'lng': -3.694064079892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Restaurante Gallego',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108559005815167534158">Martina Arevalo</a>'],
# ...

# %%
pd.json_normalize(t_page['results'])
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL                C. de San Modesto, 44, 28034 Madrid
# 1      OPERATIONAL        Calle de Modesto Lafuente, 64, 28003 Madrid
# 2      OPERATIONAL      C. de Sor Ángela de la Cruz, 22, 28020 Madrid
# 3      OPERATIONAL             Av. de Concha Espina, 55, 28016 Madrid
# 4      OPERATIONAL              C. del Padre Damián, 44, 28036 Madrid
# 5      OPERATIONAL            Av. del General Perón, 30, 28020 Madrid
# 6      OPERATIONAL            C. del Aviador Zorita, 32, 28020 Madrid
# 7      OPERATIONAL       C. del Poeta Joan Maragall, 58, 28020 Madrid
# 8      OPERATIONAL          C. de Arturo Soria, 126-128, 28043 Madrid
# 9      OPERATIONAL                 C. del Cañaveral, 19, 28029 Madrid
# 10     OPERATIONAL                 P.º de la Vaguada, 5, 28029 Madrid
# 11     OPERATIONAL    C. de Juan Hurtado de Mendoza, 11, 28036 Madrid
# ...

# %%
df_3=pd.json_normalize(t_page['results'])

# %%
pd.concat([df_1,df_2],axis=0).reset_index()
# Out:
#     index business_status                                  formatted_address  \
# 0       0     OPERATIONAL      C. del Príncipe de Vergara, 210, 28002 Madrid
# 1       1     OPERATIONAL               C. del Pensamiento, 16, 28020 Madrid
# 2       2     OPERATIONAL       C. del Poeta Joan Maragall, 51, 28020 Madrid
# 3       3     OPERATIONAL                     Pl. de Peru, nº4, 28016 Madrid
# 4       4     OPERATIONAL                 Pl. Ángel Carbajo, 6, 28020 Madrid
# 5       5     OPERATIONAL                    C. José Silva, 22, 28043 Madrid
# 6       6     OPERATIONAL                C. de Benigno Soto, 9, 28002 Madrid
# 7       7     OPERATIONAL  Entrada al restaurante por el número 3 de la c...
# 8       8     OPERATIONAL                 Av. de los Andes, 25, 28043 Madrid
# 9       9     OPERATIONAL             Av. de Concha Espina, 12, 28036 Madrid
# 10     10     OPERATIONAL       C. del Poeta Joan Maragall, 49, 28020 Madrid
# ...

# %%
df_4=pd.concat([df_1,df_2],axis=0).reset_index()

# %%
df_5=pd.concat([df_4,df_3],axis=0).reset_index()

# %%
df_5.to_csv('fourthsixty.csv')

# %% [markdown]
# # Fifth set of requests

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants&location=40.49439997257868,-3.657310009002686&radius=3000&region=es&type=restaurant&key=AIzaSyCTikq4DDzQxEd2UfsgSr-S3ImmOfAvbt8"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

pageone = response.json()

# %%
pageone
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AfLeUgPbXt_KeTFDqd_GQH1gKLuviFZFbS_T_cxD5K1pRzWg956VLv8VMaLlKCK8zSlJ0aIYfIQtT-DQKRe_JUrg5I4c5HVxlKvzC3IaYFZlyOG3lkn51HchhMk5p2pweW4u4O_LCPdxqn_d35Gju_hCducGmYv4uxEtpbNF1pTMyxHJQcr4CyckqHurBJsYhHPke0s4wKl3gFi0HJ_BrmPpPIG-fkepHi6ahmp6-BsvGDN45ZyXeEXRu0Q8o4Vs7iu6Uwk93ZtQ0kFXfybt5NiOkqmX5pN_5ycSZsnPLPsEEYDkqtfsDhURaSuGmCywNM5FxUn6YpPOAUf_5HC0LYrFfC7uZJ-Hh5N6MOeOc5rdMjzeER9tfoUfqiC_evmFHksB7KxE72nTukup9DU07rNbEVC2MMd5YeLAtHqsfHd7HI6ZueIbwV12wFrt5wFWibl1rjdlk01sK6_OfuwRKWOstxEZ3DQ',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Calle de la Virgen de Aránzazu, 4, 28034 Madrid',
#    'geometry': {'location': {'lat': 40.4856076, 'lng': -3.6897027},
#     'viewport': {'northeast': {'lat': 40.48688957989272,
#       'lng': -3.688409820107278},
#      'southwest': {'lat': 40.48418992010728, 'lng': -3.691109479892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71

#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Pl. de la Moraleja, 28109 Alcobendas, Madrid',
#    'geometry': {'location': {'lat': 40.5151064, 'lng': -3.6514748},
#     'viewport': {'northeast': {'lat': 40.51653337989273,
# ...

# %%
pd.json_normalize(pagetwo['results'])
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL       Pl. de la Moraleja, 28109 Alcobendas, Madrid
# 1      OPERATIONAL            C. de Agustín de Foxá, 31, 28036 Madrid
# 2      OPERATIONAL            C. San Juan de Ortega, 10, 28050 Madrid
# 3      OPERATIONAL            P.º de la Castellana, 257, 28046 Madrid
# 4      OPERATIONAL           C. del Príncipe Carlos, 22, 28050 Madrid
# 5      OPERATIONAL       C. del Poeta Joan Maragall, 51, 28020 Madrid
# 6      OPERATIONAL             C. de Enrique Larreta, 7, 28036 Madrid
# 7      OPERATIONAL        Av. de Europa, 10, 28108 Alcobendas, Madrid
# 8      OPERATIONAL           C. Manuel Pombo Angulo, 10, 28050 Madrid
# 9      OPERATIONAL              C/ de Sta. Virgilia, 3A, 28033 Madrid
# 10     OPERATIONAL                C. de San Leopoldo, 8, 28029 Madrid
# 11     OPERATIONAL                  C. de Caleruega, 87, 28033 Madrid
# ...

# %%
df_two=pd.json_normalize(pagetwo['results'])

# %%
firstconcat=pd.concat([df_one,df_two],axis=0)

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=restaurants&location=40.49439997257868,-3.657310009002686&radius=3000&region=es&type=restaurant&key=AIzaSyCTikq4DDzQxEd2UfsgSr-S3ImmOfAvbt8&pagetoken=AfLeUgMmJkEmOvxylGuFS84ms4I27pQpn0Th3nzoA0Km0hNS9a8lIxaIO-4vF1XTfqFgtUFlObvHydU8seeQdQaI9JlonlzHGtxl7KsN8VTyxO_AX9GvV5hoMT1RQpBXHGNK01TpKyIT_-QHbJPihPyXdPkU4XZNdujAT569UiFdNxVTPNnIvuoZvVzzGzOu1zEnJnIFBib5_2ixsGMq0WUCuIVmb_sHVVuOoy5-jef1prdq1Su_itD7WsUfw8ah10qJiGiBpC5ANzOfAoeWY66Wv6zyr6BsL_RMgKAHdIgJ3_Tq9Mu79vcnGekkceIVaDBntYdSsaTjSOTWzyKNq7wNmgDm3y4j_pz20WMF0T9LoQxW-v-82JEmtf7Kv5Kn-Y1KCPddtsHAeLC_-dMwj_e5W7E1CwYGKnJ3xYEreiKOTe9aK7EMflcF9bIGKtd6zkxtQG9v5eNruhTmkUKl_koEhDEz9KKjSEJRTXItJM5nt7JutF4RNQ2VmTC3MDxElG59FRVPvSSj3t0LKnXNNCUdRAU9ND558srFhFGNfR1Am8zQm8hQJbVeNIm6-DYu_w7mwv9UerTB_77D0g-Px8Azjh998LWoueuhOw7UJGXoPf0gkcqeZQay-I2Tru76FLnSjI-mr-hpKUaozbQLnWuVI6msrlLTXMbsxJFprK6hSO2W_Z_F"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload) 

pagethree = response.json()

# %%
pagethree
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'Calle Estafeta, Plaza de la Fuente, nº2, 28109 Alcobendas, Madrid',
#    'geometry': {'location': {'lat': 40.5143812, 'lng': -3.6526794},
#     'viewport': {'northeast': {'lat': 40.51568247989272,
#       'lng': -3.651212320107278},
#      'southwest': {'lat': 40.51298282010728, 'lng': -3.653911979892722}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Restaurante La Penela Moraleja',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111087582404712788330">Paquito Rodriguez</a>'],
# ...

# %%
df_three=pd.json_normalize(pagethree['results'])

# %%
df_three
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL  Calle Estafeta, Plaza de la Fuente, nº2, 28109...
# 1      OPERATIONAL            P.º de la Castellana, 278, 28046 Madrid
# 2      OPERATIONAL  Calle de Ntra. Sra. de Valverde, 193, 28034 Ma...
# 3      OPERATIONAL       C. del Poeta Joan Maragall, 49, 28020 Madrid
# 4      OPERATIONAL                     C. Félix Boix, 5, 28036 Madrid
# 5      OPERATIONAL                 C. de Montearagón, 9, 28033 Madrid
# 6      OPERATIONAL     C. de la Estafeta, 4, 28109 Alcobendas, Madrid
# 7      OPERATIONAL                 C. del Cañaveral, 19, 28029 Madrid
# 8      OPERATIONAL     C. de la Estafeta, 2, 28109 Alcobendas, Madrid
# 9      OPERATIONAL               C. del Mar de Aral, 16, 28033 Madrid
# 10     OPERATIONAL      Av. del Ing. Emilio Herrera, 37, 28050 Madrid
# 11     OPERATIONAL    Paseo de la Castellana, 259B. Bis, 28046 Madrid
# ...

# %%
fifthsixty = pd.concat([firstconcat,df_three],axis=0)
fifthsixty
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL    Calle de la Virgen de Aránzazu, 4, 28034 Madrid
# 1      OPERATIONAL            P.º de la Castellana, 254, 28046 Madrid
# 2      OPERATIONAL                     Calle Xaudaró, 2, 28034 Madrid
# 3      OPERATIONAL       P.º de la Tierra de Melide, 42, 28050 Madrid
# 4      OPERATIONAL                   Pl. Tres Olivos, 9, 28034 Madrid
# 5      OPERATIONAL            P.º de la Castellana, 251, 28046 Madrid
# 6      OPERATIONAL       Calle de Hospital de Órbigo, 1, 28050 Madrid
# 7      OPERATIONAL            P.º de la Castellana, 260, 28046 Madrid
# 8      OPERATIONAL  Av. de Europa, 13, Local B, 28108 Alcobendas, ...
# 9      OPERATIONAL        Av. de Europa, 10, 28100 Alcobendas, Madrid
# 10     OPERATIONAL           C. del Príncipe Carlos, 21, 28050 Madrid
# 11     OPERATIONAL  Real Club La Moraleja Campo 2, Cam. Viejo del ...
# ...

# %%
fifthsixty.to_csv('fifthsixtygoogle.csv')

# %%
def cleanjason(json_file):
    return pd.DataFrame(pd.json_normalize(json_file['results']))

# %%
cleanjason(pageone)
# Out:
#    business_status                                  formatted_address  \
# 0      OPERATIONAL    Calle de la Virgen de Aránzazu, 4, 28034 Madrid
# 1      OPERATIONAL            P.º de la Castellana, 254, 28046 Madrid
# 2      OPERATIONAL                     Calle Xaudaró, 2, 28034 Madrid
# 3      OPERATIONAL       P.º de la Tierra de Melide, 42, 28050 Madrid
# 4      OPERATIONAL                   Pl. Tres Olivos, 9, 28034 Madrid
# 5      OPERATIONAL            P.º de la Castellana, 251, 28046 Madrid
# 6      OPERATIONAL       Calle de Hospital de Órbigo, 1, 28050 Madrid
# 7      OPERATIONAL            P.º de la Castellana, 260, 28046 Madrid
# 8      OPERATIONAL  Av. de Europa, 13, Local B, 28108 Alcobendas, ...
# 9      OPERATIONAL        Av. de Europa, 10, 28100 Alcobendas, Madrid
# 10     OPERATIONAL           C. del Príncipe Carlos, 21, 28050 Madrid
# 11     OPERATIONAL  Real Club La Moraleja Campo 2, Cam. Viejo del ...
# ...
